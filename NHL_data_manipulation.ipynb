# %%
# Import package
import pandas as pd

# %%
# Import datasets
df1 = pd.read_csv(r"C:\Users\Valtteri Kimmo\Downloads\skaters_23_24.csv")
df2 = pd.read_csv(r"C:\Users\Valtteri Kimmo\Downloads\skaters_22_23.csv")
df3 = pd.read_csv(r"C:\Users\Valtteri Kimmo\Downloads\skaters_21_22.csv")

# %%
# Combine the datasets
df = pd.concat([df1, df2, df3], ignore_index=True)

#Dimension of dataset
df.shape
# Out:
# (14390, 154)

# %%
#dropping columns Im not interested in

df = df[['playerId', 'season', 'name', 'team', 'position', 'situation', 'games_played','gameScore',
         'icetime', 'shifts',  'onIce_xGoalsPercentage', 'offIce_xGoalsPercentage', 
         #'onIce_corsiPercentage', 'offIce_corsiPercentage', 'onIce_fenwickPercentage', 'offIce_fenwickPercentage', 
         'iceTimeRank', 'I_F_xOnGoal', 'I_F_xGoals', 'I_F_xRebounds', 'I_F_xFreeze', 'I_F_xPlayStopped',
         'I_F_xPlayContinuedInZone', 'I_F_xPlayContinuedOutsideZone',
         #'I_F_flurryAdjustedxGoals', 'I_F_scoreVenueAdjustedxGoals', 'I_F_flurryScoreVenueAdjustedxGoals',
         'I_F_primaryAssists',
         'I_F_secondaryAssists', 'I_F_shotsOnGoal', 'I_F_missedShots', 'I_F_blockedShotAttempts', 'I_F_shotAttempts',
         'I_F_points', 'I_F_goals', 'I_F_rebounds', 'I_F_reboundGoals', 'I_F_freeze', 'I_F_playStopped',
         'I_F_playContinuedInZone', 'I_F_playContinuedOutsideZone', 'I_F_savedShotsOnGoal', 
         'I_F_savedUnblockedShotAttempts', 'penalties', 'I_F_penalityMinutes', 'I_F_faceOffsWon', 
         'I_F_hits', 'I_F_takeaways', 'I_F_giveaways', 'I_F_lowDangerShots', 'I_F_mediumDangerShots',
         'I_F_highDangerShots', 'I_F_lowDangerxGoals', 'I_F_mediumDangerxGoals', 'I_F_highDangerxGoals',
         'I_F_lowDangerGoals', 'I_F_mediumDangerGoals', 'I_F_highDangerGoals',
         #'I_F_scoreAdjustedShotsAttempts', 
         'I_F_unblockedShotAttempts', 
         #'I_F_scoreAdjustedUnblockedShotAttempts',
         'I_F_dZoneGiveaways',
         'I_F_xGoalsFromxReboundsOfShots', 'I_F_xGoalsFromActualReboundsOfShots', 'I_F_reboundxGoals', 
         'I_F_xGoals_with_earned_rebounds', 
         #'I_F_xGoals_with_earned_rebounds_scoreAdjusted','I_F_xGoals_with_earned_rebounds_scoreFlurryAdjusted',
         'I_F_shifts', 'I_F_oZoneShiftStarts', 
         'I_F_dZoneShiftStarts', 'I_F_neutralZoneShiftStarts', 'I_F_flyShiftStarts', 'I_F_oZoneShiftEnds', 
         'I_F_dZoneShiftEnds', 'I_F_neutralZoneShiftEnds', 'I_F_flyShiftEnds', 'faceoffsWon', 'faceoffsLost','timeOnBench',
         'penalityMinutes', 'penalityMinutesDrawn', 'penaltiesDrawn', 'shotsBlockedByPlayer',
         'OnIce_F_xOnGoal', 'OnIce_F_xGoals',
         #'OnIce_F_flurryAdjustedxGoals', 'OnIce_F_scoreVenueAdjustedxGoals', 
         #'OnIce_F_flurryScoreVenueAdjustedxGoals',
         'OnIce_F_shotsOnGoal', 'OnIce_F_missedShots', 
         'OnIce_F_blockedShotAttempts', 'OnIce_F_shotAttempts', 'OnIce_F_goals', 'OnIce_F_rebounds', 
         'OnIce_F_reboundGoals', 'OnIce_F_lowDangerShots', 'OnIce_F_mediumDangerShots', 'OnIce_F_highDangerShots', 
         'OnIce_F_lowDangerxGoals', 'OnIce_F_mediumDangerxGoals', 'OnIce_F_highDangerxGoals', 'OnIce_F_lowDangerGoals',
         'OnIce_F_mediumDangerGoals', 'OnIce_F_highDangerGoals',
         #'OnIce_F_scoreAdjustedShotsAttempts',
         'OnIce_F_unblockedShotAttempts', #'OnIce_F_scoreAdjustedUnblockedShotAttempts',
         'OnIce_F_xGoalsFromxReboundsOfShots', 'OnIce_F_xGoalsFromActualReboundsOfShots', 'OnIce_F_reboundxGoals',
         'OnIce_F_xGoals_with_earned_rebounds',
         #'OnIce_F_xGoals_with_earned_rebounds_scoreAdjusted', 'OnIce_F_xGoals_with_earned_rebounds_scoreFlurryAdjusted',
         'OnIce_A_xOnGoal', 'OnIce_A_xGoals',
         #'OnIce_A_flurryAdjustedxGoals', 'OnIce_A_scoreVenueAdjustedxGoals', 'OnIce_A_flurryScoreVenueAdjustedxGoals',
         'OnIce_A_shotsOnGoal', 'OnIce_A_missedShots', 'OnIce_A_blockedShotAttempts', 'OnIce_A_shotAttempts',
         'OnIce_A_goals', 'OnIce_A_rebounds', 'OnIce_A_reboundGoals', 'OnIce_A_lowDangerShots',
         'OnIce_A_mediumDangerShots', 'OnIce_A_highDangerShots', 'OnIce_A_lowDangerxGoals',
         'OnIce_A_mediumDangerxGoals', 'OnIce_A_highDangerxGoals', 'OnIce_A_lowDangerGoals',
         'OnIce_A_mediumDangerGoals', 'OnIce_A_highDangerGoals',
         #'OnIce_A_scoreAdjustedShotsAttempts',
         'OnIce_A_unblockedShotAttempts',
         #'OnIce_A_scoreAdjustedUnblockedShotAttempts',
         'OnIce_A_xGoalsFromxReboundsOfShots', 'OnIce_A_xGoalsFromActualReboundsOfShots', 'OnIce_A_reboundxGoals',
         'OnIce_A_xGoals_with_earned_rebounds',
         #'OnIce_A_xGoals_with_earned_rebounds_scoreAdjusted','OnIce_A_xGoals_with_earned_rebounds_scoreFlurryAdjusted',
         'OffIce_F_xGoals', 'OffIce_A_xGoals',
         'OffIce_F_shotAttempts', 'OffIce_A_shotAttempts', 'xGoalsForAfterShifts', 'xGoalsAgainstAfterShifts',
         #'corsiForAfterShifts', 'corsiAgainstAfterShifts', 'fenwickForAfterShifts', 'fenwickAgainstAfterShifts'
        ]]

# %%
#Changing datatypes on specified columns
df['playerId'] = df['playerId'].astype(object)
df['season'] = df['season'].astype(object)

# Changing dataypes for columns with name that includes letter 'x', excluding first 8 columns
for i, col in enumerate(df.columns):
    if i >= 8 and 'x' not in col:
        # Directly assign to the column using the column name
        df[col] = df[col].astype('int64')

for col, dtype in zip(df.columns, df.dtypes):
    print(f'{col:50} {dtype}')
# Out:
# playerId                                           object
# season                                             object
# name                                               object
# team                                               object
# position                                           object
# situation                                          object
# games_played                                       int64
# gameScore                                          float64
# icetime                                            int64
# shifts                                             int64
# onIce_xGoalsPercentage                             float64
# offIce_xGoalsPercentage                            float64
# iceTimeRank                                        int64
# I_F_xOnGoal                                        float64
# I_F_xGoals                                         float64
# I_F_xRebounds                                      float64
# I_F_xFreeze                                        float64
# I_F_xPlayStopped                                   float64
# I_F_xPlayContinuedInZone                           float64
# I_F_xPlayContinuedOutsideZone                      float64
# I_F_primaryAssists                                 int64
# I_F_secondaryAssists                               int64
# I_F_shotsOnGoal                                    int64
# I_F_missedShots                                    int64
# I_F_blockedShotAttempts                            int64
# I_F_shotAttempts                                   int64
# I_F_points                                         int64
# I_F_goals                                          int64
# I_F_rebounds                                       int64
# I_F_reboundGoals                                   int64
# I_F_freeze                                         int64
# I_F_playStopped                                    int64
# I_F_playContinuedInZone                            int64
# I_F_playContinuedOutsideZone                       int64
# I_F_savedShotsOnGoal                               int64
# I_F_savedUnblockedShotAttempts                     int64
# penalties                                          int64
# I_F_penalityMinutes                                int64
# I_F_faceOffsWon                                    int64
# I_F_hits                                           int64
# I_F_takeaways                                      int64
# I_F_giveaways                                      int64
# I_F_lowDangerShots                                 int64
# I_F_mediumDangerShots                              int64
# I_F_highDangerShots                                int64
# I_F_lowDangerxGoals                                float64
# I_F_mediumDangerxGoals                             float64
# I_F_highDangerxGoals                               float64
# I_F_lowDangerGoals                                 int64
# I_F_mediumDangerGoals                              int64
# I_F_highDangerGoals                                int64
# I_F_unblockedShotAttempts                          int64
# I_F_dZoneGiveaways                                 int64
# I_F_xGoalsFromxReboundsOfShots                     float64
# I_F_xGoalsFromActualReboundsOfShots                float64
# I_F_reboundxGoals                                  float64
# I_F_xGoals_with_earned_rebounds                    float64
# I_F_shifts                                         int64
# I_F_oZoneShiftStarts                               int64
# I_F_dZoneShiftStarts                               int64
# I_F_neutralZoneShiftStarts                         int64
# I_F_flyShiftStarts                                 int64
# I_F_oZoneShiftEnds                                 int64
# I_F_dZoneShiftEnds                                 int64
# I_F_neutralZoneShiftEnds                           int64
# I_F_flyShiftEnds                                   int64
# faceoffsWon                                        int64
# faceoffsLost                                       int64
# timeOnBench                                        int64
# penalityMinutes                                    int64
# penalityMinutesDrawn                               int64
# penaltiesDrawn                                     int64
# shotsBlockedByPlayer                               int64
# OnIce_F_xOnGoal                                    float64
# OnIce_F_xGoals                                     float64
# OnIce_F_shotsOnGoal                                int64
# OnIce_F_missedShots                                int64
# OnIce_F_blockedShotAttempts                        int64
# OnIce_F_shotAttempts                               int64
# OnIce_F_goals                                      int64
# OnIce_F_rebounds                                   int64
# OnIce_F_reboundGoals                               int64
# OnIce_F_lowDangerShots                             int64
# OnIce_F_mediumDangerShots                          int64
# OnIce_F_highDangerShots                            int64
# OnIce_F_lowDangerxGoals                            float64
# OnIce_F_mediumDangerxGoals                         float64
# OnIce_F_highDangerxGoals                           float64
# OnIce_F_lowDangerGoals                             int64
# OnIce_F_mediumDangerGoals                          int64
# OnIce_F_highDangerGoals                            int64
# OnIce_F_unblockedShotAttempts                      int64
# OnIce_F_xGoalsFromxReboundsOfShots                 float64
# OnIce_F_xGoalsFromActualReboundsOfShots            float64
# OnIce_F_reboundxGoals                              float64
# OnIce_F_xGoals_with_earned_rebounds                float64
# OnIce_A_xOnGoal                                    float64
# OnIce_A_xGoals                                     float64
# OnIce_A_shotsOnGoal                                int64
# OnIce_A_missedShots                                int64
# OnIce_A_blockedShotAttempts                        int64
# OnIce_A_shotAttempts                               int64
# OnIce_A_goals                                      int64
# OnIce_A_rebounds                                   int64
# OnIce_A_reboundGoals                               int64
# OnIce_A_lowDangerShots                             int64
# OnIce_A_mediumDangerShots                          int64
# OnIce_A_highDangerShots                            int64
# OnIce_A_lowDangerxGoals                            float64
# OnIce_A_mediumDangerxGoals                         float64
# OnIce_A_highDangerxGoals                           float64
# OnIce_A_lowDangerGoals                             int64
# OnIce_A_mediumDangerGoals                          int64
# OnIce_A_highDangerGoals                            int64
# OnIce_A_unblockedShotAttempts                      int64
# OnIce_A_xGoalsFromxReboundsOfShots                 float64
# OnIce_A_xGoalsFromActualReboundsOfShots            float64
# OnIce_A_reboundxGoals                              float64
# OnIce_A_xGoals_with_earned_rebounds                float64
# OffIce_F_xGoals                                    float64
# OffIce_A_xGoals                                    float64
# OffIce_F_shotAttempts                              int64
# OffIce_A_shotAttempts                              int64
# xGoalsForAfterShifts                               float64
# xGoalsAgainstAfterShifts                           float64

# %%
# I noticed names were not always consistent across datasets so I want to fix that


consistent_names = df.groupby("playerId")["name"].first().reset_index()# First name occurence will be used
print(consistent_names)
# Out:
#       playerId               name
# 0      8465009        Zdeno Chara
# 1      8466138       Joe Thornton
# 2      8469455       Jason Spezza
# 3      8470281       Duncan Keith
# 4      8470595         Eric Staal
# ...        ...                ...
# 1249   8484314       Jiri Smejkal
# 1250   8484321  Nikolas Matinpalo
# 1251   8484325    Waltteri Merela
# 1252   8484326        Patrik Koch
# 1253   8484911        Collin Graf
#
# [1254 rows x 2 columns]

# %%
name_mapping = dict(zip(consistent_names["playerId"], consistent_names["name"]))

# Replace names in the original DataFrame
df["name"] = df["playerId"].map(name_mapping)
print(df)
# Out:
#       playerId season             name team position situation  games_played  \
# 0      8480950   2023  Ilya Lyubushkin  TOR        D     other            74
# 1      8480950   2023  Ilya Lyubushkin  TOR        D       all            74
# 2      8480950   2023  Ilya Lyubushkin  TOR        D      5on5            74
# 3      8480950   2023  Ilya Lyubushkin  TOR        D      4on5            74
# 4      8480950   2023  Ilya Lyubushkin  TOR        D      5on4            74
# ...        ...    ...              ...  ...      ...       ...           ...
# 14385  8475176   2021       Ryan Ellis  PHI        D     other             4
# 14386  8475176   2021       Ryan Ellis  PHI        D       all             4
# 14387  8475176   2021       Ryan Ellis  PHI        D      5on5             4
# 14388  8475176   2021       Ryan Ellis  PHI        D      4on5             4
# 14389  8475176   2021       Ryan Ellis  PHI        D      5on4             4
#
#        gameScore  icetime  shifts  ...  OnIce_A_xGoalsFromxReboundsOfShots  \
# 0           5.08     2881      56  ...                                1.21
# 1           4.47    76034    1717  ...                               13.97
# 2           4.47    61758    1389  ...                                7.60
# 3           3.43    11271     259  ...                                5.15
# 4           3.45      124      13  ...                                0.00
# ...          ...      ...     ...  ...                                 ...
# 14385       3.85      240       4  ...                                0.10
# 14386       4.10     5473     117  ...                                0.77
# 14387       4.10     4263      90  ...                                0.36
# 14388       3.45      579      13  ...                                0.30
# 14389       4.10      391      10  ...                                0.01
#
#        OnIce_A_xGoalsFromActualReboundsOfShots  OnIce_A_reboundxGoals  \
# 0                                         2.53                   2.53
# 1                                        19.75                  19.75
# 2                                        11.57                  11.57
# 3                                         5.65                   5.65
# 4                                         0.00                   0.00
# ...                                        ...                    ...
# 14385                                     0.00                   0.00
# 14386                                     0.73                   0.73
# 14387                                     0.67                   0.67
# 14388                                     0.07                   0.07
# 14389                                     0.00                   0.00
#
#        OnIce_A_xGoals_with_earned_rebounds  OffIce_F_xGoals  OffIce_A_xGoals  \
# 0                                     8.75            18.00            21.61
# 1                                    78.77           176.13           171.61
# 2                                    43.73           107.09           104.80
# 3                                    26.21             4.28            27.86
# 4                                     0.00             6.03             1.37
# ...                                    ...              ...              ...
# 14385                                 0.66             0.24             2.22
# 14386                                 3.61             7.50            11.20
# 14387                                 1.97             6.29             8.03
# 14388                                 0.96             0.10             0.05
# 14389                                 0.03             0.58             0.14
#
#        OffIce_F_shotAttempts  OffIce_A_shotAttempts  xGoalsForAfterShifts  \
# 0                        195                    191                  0.11
# 1                       3226                   3132                  0.00
# 2                       2302                   2303                  6.54
# 3                         68                    482                  0.11
# 4                        106                     19                  0.00
# ...                      ...                    ...                   ...
# 14385                      5                      8                  0.09
# 14386                    136                    160                  0.00
# 14387                    115                    136                  0.29
# 14388                      1                      6                  0.00
# 14389                     14                      3                  0.00
#
#        xGoalsAgainstAfterShifts
# 0                          0.02
# 1                          0.00
# 2                          0.64
# 3                          0.00
# 4                          0.00
# ...                         ...
# 14385                      0.00
# 14386                      0.00
# 14387                      0.00
# 14388                      0.00
# 14389                      0.00
#
# [14390 rows x 125 columns]

# %%
#Check if playerId+name+season+situation combo has any duplicates in data
duplicates = df[['playerId','name','season','situation']].duplicated()

duplicates_rows = df[duplicates]
duplicates_rows.shape
# Out:
# (0, 125)

# %%
# Save the combined DataFrame to the specified path
df.to_csv(r'C:\Users\Valtteri Kimmo\Downloads\skaters_21_24.csv', index=False)
